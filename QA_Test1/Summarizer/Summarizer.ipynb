# %%
# spaCy 載入中文模型
import spacy
import zh_core_web_lg
import neuralcoref

nlp = zh_core_web_lg.load()
neuralcoref.add_to_pipe(nlp)

# summarizer 載入中文模型
from summarizer import Summarizer
from summarizer.sentence_handler import SentenceHandler
from spacy.lang.zh import Chinese
from transformers import *

# Load model, model config and tokenizer via Transformers
modelName = "bert-base-chinese" # 可以換成自己常用的
custom_config = AutoConfig.from_pretrained(modelName)
custom_config.output_hidden_states=True
custom_tokenizer = AutoTokenizer.from_pretrained(modelName)
custom_model = AutoModel.from_pretrained(modelName, config=custom_config)

model = Summarizer(
    custom_model=custom_model,
    custom_tokenizer=custom_tokenizer,
    sentence_handler = SentenceHandler(language=Chinese)
    )
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python36\lib\importlib\_bootstrap.py:219: RuntimeWarning: spacy.morphology.Morphology size changed, may indicate binary incompatibility. Expected 104 from C header, got 112 from PyObject
#   return f(*args, **kwds)
# C:\Users\user\AppData\Local\Programs\Python\Python36\lib\importlib\_bootstrap.py:219: RuntimeWarning: spacy.vocab.Vocab size changed, may indicate binary incompatibility. Expected 96 from C header, got 112 from PyObject
#   return f(*args, **kwds)
# C:\Users\user\AppData\Local\Programs\Python\Python36\lib\importlib\_bootstrap.py:219: RuntimeWarning: spacy.tokens.span.Span size changed, may indicate binary incompatibility. Expected 72 from C header, got 80 from PyObject
#   return f(*args, **kwds)
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\user\AppData\Local\Temp\jieba.cache
# Loading model cost 0.682 seconds.
# Prefix dict has been built successfully.
# ...

# %%
body = '曾世雄前於民國98年間因違反毒品危害防制條例等案件，分經本院以98年度易字第1500號判處有期徒刑6月及3月，應執行有期徒刑7月，如易科罰金以新台幣1000元折算1日確定，已於99年4月13日易科罰金執行完畢，詎不知警惕，曾世雄與黃國賓、趙志強為朋友關係，曾世雄曾借趙志強新台幣2萬元，黃國賓則借趙志強1萬元，經曾世雄等多次催討，趙志強均未清償，民國104年1月16日，曾世雄與趙志強又因債務糾紛在電話中發生口角，趙志強竟對曾世雄出言挑釁，曾雄世乃於同日上午1時許，約同黃國賓至趙志強位臺南市○區○○路0段00號住處準備協商債務問題，並自備剪刀、木棍到場，而趙志強亦準備鐵管一支。曾世雄到達上開住處前面，即基於傷害之犯意，先以準備之木棍揮向趙志強，惟經趙志強閃掉後，趙志強隨即以準備之鐵管攻擊曾世雄，經曾世雄以左手臂架開（未檢具傷單），二人並進而發生扭打，其後曾世雄並趁趙志強未注意之際，拿出自備之剪刀刺向趙志強之左下腹及臀部數次，造成趙志強因而受有左胸2處穿刺傷氣胸血胸、左腹1處穿刺傷併腹部疝氣及小腸拑頓、後背及臀部共7處穿刺傷，穿刺傷各約1-2公分寬之傷害。'
print(len(body))
result = model(body)
full = ''.join(result)
print(full) # 摘要出來的句子
print(len(full))
# Out:
# 482
# 曾世雄前於民國98年間因違反毒品危害防制條例等案件，分經本院以98年度易字第1500號判處有期徒刑6月及3月，應執行有期徒刑7月，如易科罰金以新台幣1000元折算1日確定，已於99年4月13日易科罰金執行完畢，詎不知警惕，曾世雄與黃國賓、趙志強為朋友關係，曾世雄曾借趙志強新台幣2萬元，黃國賓則借趙志強1萬元，經曾世雄等多次催討，趙志強均未清償，民國104年1月16日，曾世雄與趙志強又因債務糾紛在電話中發生口角，趙志強竟對曾世雄出言挑釁，曾雄世乃於同日上午1時許，約同黃國賓至趙志強位臺南市○區○○路0段00號住處準備協商債務問題，並自備剪刀、木棍到場，而趙志強亦準備鐵管一支。
# 290
